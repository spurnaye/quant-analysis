# %%
import pandas as pd
import Quandl
import numpy as np

snp_data = Quandl.get('YAHOO/INDEX_GSPC')
snp_data.columns = ['Open','High','Low','Close','Volume','AdjustedClose']
percentage_change = snp_data.AdjustedClose.pct_change()
percentage_change.fillna(0)
percentage_change.autocorr()
# Out:
# 0.027558097594043013

# %%
percentage_change.autocorr?

# %%
from pandas.tools.plotting import autocorrelation_plot

# %%
autocorrelation_plot(percentage_change)

# %%
from __future__ import print_function
import numpy as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt

import statsmodels.api as sm
from statsmodels.graphics.api import qqplot

# %%
sm.graphics.tsa.plot_acf(percentage_change.values.squeeze(), lags=10)

# %%
sm.graphics.tsa.plot_pacf(percentage_change.values.squeeze(), lags=5)
